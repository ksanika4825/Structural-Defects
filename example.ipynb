# %%
pip install pillow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 9.9 MB/s  0:00:00m eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image

# %%
image_link = r'/Users/akhileshjanib/Documents/image.jpeg'

# %%
defect_image = Image.open(image_link)

# %%
defect_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=274x184>
